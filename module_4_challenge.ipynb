# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
column_names = df.columns
print(column_names)
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
summary_stats = df.describe()
print(summary_stats)
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

# %%
# What three item categories had the most entries?
category_counts = df['category'].value_counts()

top_categories = category_counts.head(3)

top_categories
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
most_common_category = top_categories.index[0]

most_common_category_data = df[df['category'] == most_common_category]

subcategory_counts = most_common_category_data['subcategory'].value_counts()

most_common_subcategory = subcategory_counts.index[0]

most_common_subcategory
# Out:
# 'bathroom supplies'

# %%
# Which five clients had the most entries in the data?
client_counts = df['client_id'].value_counts()

top_clients = client_counts.head(5)

top_clients
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.

top_client_ids = top_clients.index.tolist()

top_client_ids
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the
# client with the most entries order order?

client_data = df[df['client_id'] == 33615]

total_units_ordered = client_data['qty'].sum()

total_units_ordered
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty

df['subtotal'] = df['unit_price'] * df['qty']

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.

df['total_weight'] = df['unit_weight'] * df['qty']

df['shipping_price'] = df['total_weight'].apply(lambda x: 7 if x > 50 else 10) * df['total_weight']

df[df['total_weight']>50]
# Out:
#            first       last                                           job  \
# 0         Donald    Harding                                  Immunologist
# 2        Shannon     Watson                                  Immunologist
# 4      Christina   Schwartz                                  Chiropractor
# 5        Jessica      Reyes  Production designer, theatre/television/film
# 6          Brian      Moore                                       Barista
# ...          ...        ...                                           ...
# 54634     Lauren      Reese                                Radio producer
# 54635    Derrick      Moore                                      Musician
# 54636     Monica  Gutierrez                              Graphic designer
# 54637      Wanda    Solomon                                  Toxicologist
# 54638     Dwayne       Bell                       Chief Financial Officer
#
#                      phone                                email  client_id  \
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

sales_tax_rate = 1.0925

df['total_price'] = round((df['subtotal'] + df['shipping_price']) * sales_tax_rate, 2)

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).

df['line_cost'] = df['unit_cost'] * df['qty'] + df['shipping_price']

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price

df['profit'] = df['total_price'] - df['line_cost']

df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above

order_2742071 = df[df['order_id'] == 2742071]
calculated_total_2742071 = order_2742071['total_price'].sum()
receipt_total_2742071 = 152811.89  # Total price from the receipt

print(calculated_total_2742071)
print(receipt_total_2742071)
print(calculated_total_2742071 == receipt_total_2742071)

#floating point rounding error
# Out:
# 152811.88999999998
# 152811.89
# False

# %%
order_2173913 = df[df['order_id'] == 2173913]
calculated_total_2173913 = order_2173913['total_price'].sum()
receipt_total_2173913 = 162388.71  # Total price from the receipt

print(calculated_total_2173913)
print(receipt_total_2173913)
print(calculated_total_2173913 == receipt_total_2173913)
# Out:
# 162388.71
# 162388.71
# True

# %%
order_6128929 = df[df['order_id'] == 6128929]
calculated_total_6128929 = order_6128929['total_price'].sum()
receipt_total_6128929 = 923441.25  # Total price from the receipt

print(calculated_total_6128929)
print(receipt_total_6128929)
print(calculated_total_6128929 == receipt_total_6128929)
# Out:
# 923441.25
# 923441.25
# True

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.


top_5_clients_spend_total = df.loc[df['client_id'].isin(top_clients.index), ['total_price', 'client_id']]

top_5_clients_spend_total.groupby('client_id')['total_price'].sum()
# Out:
# client_id
# 10033     689274.95
# 10091    1825072.92
# 10218    3683119.77
# 10351    1712403.23
# 10435    8722369.83
#             ...
# 54350    7057547.97
# 54400    3757304.89
# 54471    1706691.13
# 54518     489544.75
# 54596    2209398.96
# Name: total_price, Length: 499, dtype: float64

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

top_clients_summary = top_clients.sort_values('profit', ascending=False)

top_clients['Total Revenue'] = top_clients['qty'] * top_clients['unit_price']

# Print the summary DataFrame
print(top_clients)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6644\3073938774.py in ?()
#       2 # for the top 5 clients with the following information:
#       3 # total units purchased, total shipping price,
#       4 # total revenue, and total profit. Sort by total profit.
#       5
# ----> 6 top_clients_summary = top_clients.sort_values('profit', ascending=False)
#       7
#       8 top_clients['Total Revenue'] = top_clients['qty'] * top_clients['unit_price']
#       9
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6943             )
#    6944         elif len(by):
#    6945             # len(by) == 1
#    6946
# -> 6947             k = self._get_label_or_level_values(by[0], axis=axis)
#    6948
# ...

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

top_clients = top_clients.rename(columns={
    'units_purchased': 'Total Units_Purchased',
    'shipping_price': 'Total Shipping_Price',
    'revenue': 'Total Revenue',
    'profit': 'Total Profit'
})

top_clients['Total Revenue'] = top_clients['Total Revenue'] / 1000000
top_clients['Total Profit'] = top_clients['Total Profit'] / 1000000

top_clients
# Out:
#          first      last                                    job  \
# 21801    Julie  Anderson                    Exhibition designer
# 15112   Dennis   Hawkins    Social research officer, government
# 25972      Amy   Stewart              Psychologist, educational
# 23929  Michele  Mcdonald  Emergency planning/management officer
# 4063    Kendra   Garrett                 Pension scheme manager
# ...        ...       ...                                    ...
# 26881    Brian   Jackson                Human resources officer
# 14104  Sabrina   Johnson                                 Artist
# 1532    Kendra   Garrett                 Pension scheme manager
# 35061     Seth  Thompson                   Intelligence analyst
# 1830   Patrick  Espinoza                 Recruitment consultant
#
#                        phone                            email  client_id  \
# 21801             5933099462    anderson_better_4704@bell.biz      78965
# ...

# %%
# Sort the updated data by "Total Profit" form highest to lowest

top_clients_summary = top_clients.sort_values('Total Profit', ascending=False)

# Print the summary DataFrame
print(top_clients_summary)
# Out:
#              first      last                                    job  \
# 21801        Julie  Anderson                    Exhibition designer
# 15112       Dennis   Hawkins    Social research officer, government
# 25972          Amy   Stewart              Psychologist, educational
# 23929      Michele  Mcdonald  Emergency planning/management officer
# 4063        Kendra   Garrett                 Pension scheme manager
# ...            ...       ...                                    ...
# 27866       Shelby  Williams                    Colour technologist
# 21090       Daniel    Bowman                          Archaeologist
# 21190        David    Herman                                 Artist
# 13835  Christopher    Rhodes        Engineer, manufacturing systems
# 1830       Patrick  Espinoza                 Recruitment consultant
#
#                        phone                                email  client_id  \
# ...
